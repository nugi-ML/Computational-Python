# %%
from math import atan, pi

x = 10.0        # Horizontal position
y = 10.0        # Vertical position

angle = atan(y/x)

print((angle/pi)*180)
# Out:
# 45.0

# %%
import math

x = 10.0        # Horizontal position
y = 10.0        # Vertical position

angle = math.atan(y/x)

print((angle/math.pi)*180)
# Out:
# 45.0
