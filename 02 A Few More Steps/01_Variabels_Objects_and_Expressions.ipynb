# %% [markdown]
# ### **Reserved Words**

# %%
import keyword

keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# **Assignment**

# %%
x = 2
y = x

y = y + 1

y
# Out:
# 3

# %% [markdown]
# ### **Object Type and Type Conversion**

# %%
x = 2
y = 4.0
s = 'hello'

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
type(s)
# Out:
# str

# %%
x = 1
y = float(x)
y
# Out:
# 1.0

# %%
x = 1.0
y = int(x)
y
# Out:
# 1

# %% [markdown]
# ### **Automatic Type Conversion**

# %%
x = 2
x = x + 4.0
x
# Out:
# 6.0

# %% [markdown]
# ### **Division—Quotient and Remainder**

# %%
# Integer division
11//2
# Out:
# 5

# %%
# module
11%2
# Out:
# 1

# %% [markdown]
# ### **Using Parentheses**

# %%
x = 4

# %%
1.0/x+1
# Out:
# 1.25

# %%
1.0/(x+1)
# Out:
# 0.2

# %% [markdown]
# ### **Boolean Expressions**

# %%
x = 4

# %%
x > 5   # x greater than 5
# Out:
# False

# %%
x >= 5  # x greater then, or equal to 5
# Out:
# False

# %%
x < 5   # x smaller than 5
# Out:
# True

# %%
x <= 5  # x smaller then, or equal to 5
# Out:
# True

# %%
x == 4  # x equal to 4
# Out:
# True

# %%
x != 4  # x not equal to 4
# Out:
# False

# %%
x < 5 and x > 3     # x less than 5 AND x larger than 3
# Out:
# True

# %%
x == 5 or x == 4    # x equal to 5 OR x equal to 4
# Out:
# True

# %%
not x == 4          # not x equal to 4
# Out:
# False
